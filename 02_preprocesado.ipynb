# %% [markdown]
# <a href="https://colab.research.google.com/github/Santiagohvilla/Proyecto_IA-2025_2/blob/Entregas/02_preprocesado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **02 - PREPROCESADO**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os

os.environ['KAGGLE_CONFIG_DIR']="."

# %%
# !kaggle competitions download -c udea-ai-4-eng-20252-pruebas-saber-pro-colombia
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 ./kaggle.json'
# Downloading udea-ai-4-eng-20252-pruebas-saber-pro-colombia.zip to /content
#   0% 0.00/29.9M [00:00<?, ?B/s]
# 100% 29.9M/29.9M [00:00<00:00, 1.38GB/s]

# %%
# !unzip udea-ai-4-eng-20252-pruebas-saber-pro-colombia
# Out:
# Archive:  udea-ai-4-eng-20252-pruebas-saber-pro-colombia.zip
#   inflating: submission_example.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
z=pd.read_csv("train.csv")
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692500 entries, 0 to 692499
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   ID                           692500 non-null  int64
#  1   PERIODO_ACADEMICO            692500 non-null  int64
#  2   E_PRGM_ACADEMICO             692500 non-null  object
#  3   E_PRGM_DEPARTAMENTO          692500 non-null  object
#  4   E_VALORMATRICULAUNIVERSIDAD  686213 non-null  object
#  5   E_HORASSEMANATRABAJA         661643 non-null  object
#  6   F_ESTRATOVIVIENDA            660363 non-null  object
#  7   F_TIENEINTERNET              665871 non-null  object
#  8   F_EDUCACIONPADRE             669322 non-null  object
#  9   F_TIENELAVADORA              652727 non-null  object
#  10  F_TIENEAUTOMOVIL             648877 non-null  object
#  11  E_PRIVADO_LIBERTAD           692500 non-null  object
#  12  E_PAGOMATRICULAPROPIO        686002 non-null  object
#  13  F_TIENECOMPUTADOR            654397 non-null  object
#  14  F_TIENEINTERNET.1            665871 non-null  object
#  15  F_EDUCACIONMADRE             668836 non-null  object
#  16  RENDIMIENTO_GLOBAL           692500 non-null  object
#  17  INDICADOR_1                  692500 non-null  float64
#  18  INDICADOR_2                  692500 non-null  float64
#  19  INDICADOR_3                  692500 non-null  float64
#  20  INDICADOR_4                  692500 non-null  float64
# dtypes: float64(4), int64(2), object(15)
# memory usage: 111.0+ MB

# %%
z
# Out:
#             ID  PERIODO_ACADEMICO                     E_PRGM_ACADEMICO  \
# 0       904256              20212                           ENFERMERIA
# 1       645256              20212                              DERECHO
# 2       308367              20203                MERCADEO Y PUBLICIDAD
# 3       470353              20195           ADMINISTRACION DE EMPRESAS
# 4       989032              20212                           PSICOLOGIA
# ...        ...                ...                                  ...
# 692495   25096              20195                             BIOLOGIA
# 692496  754213              20212                           PSICOLOGIA
# 692497  504185              20183  ADMINISTRACIÓN EN SALUD OCUPACIONAL
# 692498  986620              20195                           PSICOLOGIA
# 692499  933374              20195                           PSICOLOGIA
#
#        E_PRGM_DEPARTAMENTO               E_VALORMATRICULAUNIVERSIDAD  \
# 0                   BOGOTÁ  Entre 5.5 millones y menos de 7 millones
# 1                ATLANTICO  Entre 2.5 millones y menos de 4 millones
# 2                   BOGOTÁ  Entre 2.5 millones y menos de 4 millones
# 3                SANTANDER  Entre 4 millones y menos de 5.5 millones
# 4                ANTIOQUIA  Entre 2.5 millones y menos de 4 millones
# ...                    ...                                       ...
# 692495          LA GUAJIRA         Entre 500 mil y menos de 1 millón
# 692496     NORTE SANTANDER  Entre 2.5 millones y menos de 4 millones
# 692497              BOGOTÁ    Entre 1 millón y menos de 2.5 millones
# 692498              TOLIMA  Entre 2.5 millones y menos de 4 millones
# 692499           ANTIOQUIA  Entre 5.5 millones y menos de 7 millones
#
#        E_HORASSEMANATRABAJA F_ESTRATOVIVIENDA F_TIENEINTERNET  \
# 0         Menos de 10 horas         Estrato 3              Si
# 1                         0         Estrato 3              No
# 2           Más de 30 horas         Estrato 3              Si
# 3                         0         Estrato 4              Si
# 4       Entre 21 y 30 horas         Estrato 3              Si
# ...                     ...               ...             ...
# 692495  Entre 11 y 20 horas         Estrato 2              Si
# 692496      Más de 30 horas         Estrato 3              Si
# 692497    Menos de 10 horas         Estrato 3              Si
# 692498    Menos de 10 horas         Estrato 1              No
# 692499      Más de 30 horas         Estrato 4              Si
#
#                           F_EDUCACIONPADRE F_TIENELAVADORA  ...  \
# 0         Técnica o tecnológica incompleta              Si  ...
# 1           Técnica o tecnológica completa              Si  ...
# 2       Secundaria (Bachillerato) completa              Si  ...
# 3                                  No sabe              Si  ...
# 4                        Primaria completa              Si  ...
# ...                                    ...             ...  ...
# 692495  Secundaria (Bachillerato) completa              Si  ...
# 692496                 Primaria incompleta              Si  ...
# 692497  Secundaria (Bachillerato) completa              Si  ...
# 692498                   Primaria completa              No  ...
# 692499  Secundaria (Bachillerato) completa              Si  ...
#
#        E_PRIVADO_LIBERTAD E_PAGOMATRICULAPROPIO F_TIENECOMPUTADOR  \
# 0                       N                    No                Si
# 1                       N                    No                Si
# 2                       N                    No                No
# 3                       N                    No                Si
# 4                       N                    No                Si
# ...                   ...                   ...               ...
# 692495                  N                    Si                Si
# 692496                  N                    No                Si
# 692497                  N                    Si                Si
# 692498                  N                    Si                Si
# 692499                  N                    No                Si
#
#        F_TIENEINTERNET.1                      F_EDUCACIONMADRE  \
# 0                     Si                             Postgrado
# 1                     No      Técnica o tecnológica incompleta
# 2                     Si    Secundaria (Bachillerato) completa
# 3                     Si    Secundaria (Bachillerato) completa
# 4                     Si                     Primaria completa
# ...                  ...                                   ...
# 692495                Si  Secundaria (Bachillerato) incompleta
# 692496                Si  Secundaria (Bachillerato) incompleta
# 692497                Si  Secundaria (Bachillerato) incompleta
# 692498                No                     Primaria completa
# 692499                Si        Técnica o tecnológica completa
#
#        RENDIMIENTO_GLOBAL INDICADOR_1  INDICADOR_2  INDICADOR_3  INDICADOR_4
# 0              medio-alto       0.322        0.208        0.310        0.267
# 1                    bajo       0.311        0.215        0.292        0.264
# 2                    bajo       0.297        0.214        0.305        0.264
# 3                    alto       0.485        0.172        0.252        0.190
# 4              medio-bajo       0.316        0.232        0.285        0.294
# ...                   ...         ...          ...          ...          ...
# 692495         medio-alto       0.237        0.271        0.271        0.311
# 692496               bajo       0.314        0.240        0.278        0.260
# 692497         medio-bajo       0.286        0.240        0.314        0.287
# 692498               bajo       0.132        0.426        0.261        0.328
# 692499               alto       0.487        0.180        0.251        0.187
#
# [692500 rows x 21 columns]

# %%
print("Cantidad de NaN por columna:")
print(z.isna().sum())
# Out:
# Cantidad de NaN por columna:
# ID                                 0
# PERIODO_ACADEMICO                  0
# E_PRGM_ACADEMICO                   0
# E_PRGM_DEPARTAMENTO                0
# E_VALORMATRICULAUNIVERSIDAD     6287
# E_HORASSEMANATRABAJA           30857
# F_ESTRATOVIVIENDA              32137
# F_TIENEINTERNET                26629
# F_EDUCACIONPADRE               23178
# F_TIENELAVADORA                39773
# F_TIENEAUTOMOVIL               43623
# E_PRIVADO_LIBERTAD                 0
# E_PAGOMATRICULAPROPIO           6498
# F_TIENECOMPUTADOR              38103
# F_TIENEINTERNET.1              26629
# F_EDUCACIONMADRE               23664
# RENDIMIENTO_GLOBAL                 0
# INDICADOR_1                        0
# INDICADOR_2                        0
# INDICADOR_3                        0
# INDICADOR_4                        0
# dtype: int64

# %% [markdown]
# Se evidencia que la columna F_TIENEINTERNET.1 está repetido, así que se descartará, además del ID de cada estudiantes ya que no es relevante para este ejercicio.

# %%
d = z.drop(columns=['ID', 'F_TIENEINTERNET.1'])
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692500 entries, 0 to 692499
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   PERIODO_ACADEMICO            692500 non-null  int64
#  1   E_PRGM_ACADEMICO             692500 non-null  object
#  2   E_PRGM_DEPARTAMENTO          692500 non-null  object
#  3   E_VALORMATRICULAUNIVERSIDAD  686213 non-null  object
#  4   E_HORASSEMANATRABAJA         661643 non-null  object
#  5   F_ESTRATOVIVIENDA            660363 non-null  object
#  6   F_TIENEINTERNET              665871 non-null  object
#  7   F_EDUCACIONPADRE             669322 non-null  object
#  8   F_TIENELAVADORA              652727 non-null  object
#  9   F_TIENEAUTOMOVIL             648877 non-null  object
#  10  E_PRIVADO_LIBERTAD           692500 non-null  object
#  11  E_PAGOMATRICULAPROPIO        686002 non-null  object
#  12  F_TIENECOMPUTADOR            654397 non-null  object
#  13  F_EDUCACIONMADRE             668836 non-null  object
#  14  RENDIMIENTO_GLOBAL           692500 non-null  object
#  15  INDICADOR_1                  692500 non-null  float64
#  16  INDICADOR_2                  692500 non-null  float64
#  17  INDICADOR_3                  692500 non-null  float64
#  18  INDICADOR_4                  692500 non-null  float64
# dtypes: float64(4), int64(1), object(14)
# memory usage: 100.4+ MB

# %% [markdown]
# Observamos los atributos que posee cada columna  para tomar decisiones sobre los datos faltantes

# %%
for columna in d.columns:
    valores_unicos = d[columna].unique()
    # Imprime el nombre de la columna y sus valores
    print(f"\nColumna: {columna}")
    print(f"Tipo de dato: {d[columna].dtype}")
    print(f"Total de valores únicos: {len(valores_unicos)}")

    # Muestra los valores  (se limitan a los primeros 20 para evitar saturar la consola)
    print(f"Valores Únicos: {valores_unicos[:20]}...")
# Out:
# Columna: PERIODO_ACADEMICO
# Tipo de dato: int64
# Total de valores únicos: 9
# Valores Únicos: [20212 20203 20195 20183 20194 20213 20184 20202 20196]...
#
# Columna: E_PRGM_ACADEMICO
# Tipo de dato: object
# Total de valores únicos: 948
# Valores Únicos: ['ENFERMERIA' 'DERECHO' 'MERCADEO Y PUBLICIDAD'
#  'ADMINISTRACION DE EMPRESAS' 'PSICOLOGIA' 'MEDICINA VETERINARIA'
#  'INGENIERIA MECANICA' 'ADMINISTRACIÓN EN SALUD OCUPACIONAL'
#  'INGENIERIA INDUSTRIAL' 'ADMINISTRACIÓN FINANCIERA' 'HOTELERIA Y TURISMO'
#  'LICENCIATURA EN CIENCIAS SOCIALES' 'LICENCIATURA EN PEDAGOGIA INFANTIL'
#  'COMUNICACION SOCIAL' 'CIENCIA POLITICA'
#  'PROFESIONAL EN GESTIÓN DE LA SEGURIDAD Y LA SALUD LABORAL'
#  'MAESTRO EN MÚSICA' 'INGENIERIA MECATRONICA' 'TRABAJO SOCIAL'
#  'LICENCIATURA EN BIOLOGIA Y EDUCACION AMBIENTAL']...
#
# Columna: E_PRGM_DEPARTAMENTO
# Tipo de dato: object
# Total de valores únicos: 31
# Valores Únicos: ['BOGOTÁ' 'ATLANTICO' 'SANTANDER' 'ANTIOQUIA' 'HUILA' 'SUCRE' 'CAQUETA'
#  'CUNDINAMARCA' 'BOLIVAR' 'TOLIMA' 'VALLE' 'QUINDIO' 'RISARALDA' 'CORDOBA'
#  'META' 'LA GUAJIRA' 'BOYACA' 'NARIÑO' 'CAUCA' 'NORTE SANTANDER']...
#
# Columna: E_VALORMATRICULAUNIVERSIDAD
# Tipo de dato: object
# Total de valores únicos: 9
# Valores Únicos: ['Entre 5.5 millones y menos de 7 millones'
#  'Entre 2.5 millones y menos de 4 millones'
#  'Entre 4 millones y menos de 5.5 millones' 'Más de 7 millones'
#  'Entre 1 millón y menos de 2.5 millones'
#  'Entre 500 mil y menos de 1 millón' 'Menos de 500 mil'
#  'No pagó matrícula' nan]...
#
# Columna: E_HORASSEMANATRABAJA
# Tipo de dato: object
# Total de valores únicos: 6
# Valores Únicos: ['Menos de 10 horas' '0' 'Más de 30 horas' 'Entre 21 y 30 horas'
#  'Entre 11 y 20 horas' nan]...
#
# Columna: F_ESTRATOVIVIENDA
# Tipo de dato: object
# Total de valores únicos: 8
# Valores Únicos: ['Estrato 3' 'Estrato 4' 'Estrato 5' 'Estrato 2' 'Estrato 1' nan
#  'Estrato 6' 'Sin Estrato']...
#
# Columna: F_TIENEINTERNET
# Tipo de dato: object
# Total de valores únicos: 3
# Valores Únicos: ['Si' 'No' nan]...
#
# Columna: F_EDUCACIONPADRE
# Tipo de dato: object
# Total de valores únicos: 13
# Valores Únicos: ['Técnica o tecnológica incompleta' 'Técnica o tecnológica completa'
#  'Secundaria (Bachillerato) completa' 'No sabe' 'Primaria completa'
#  'Educación profesional completa' 'Educación profesional incompleta'
#  'Primaria incompleta' 'Postgrado' nan
#  'Secundaria (Bachillerato) incompleta' 'Ninguno' 'No Aplica']...
#
# Columna: F_TIENELAVADORA
# Tipo de dato: object
# Total de valores únicos: 3
# Valores Únicos: ['Si' 'No' nan]...
#
# Columna: F_TIENEAUTOMOVIL
# Tipo de dato: object
# Total de valores únicos: 3
# Valores Únicos: ['Si' 'No' nan]...
#
# Columna: E_PRIVADO_LIBERTAD
# Tipo de dato: object
# Total de valores únicos: 2
# Valores Únicos: ['N' 'S']...
#
# Columna: E_PAGOMATRICULAPROPIO
# Tipo de dato: object
# Total de valores únicos: 3
# Valores Únicos: ['No' 'Si' nan]...
#
# Columna: F_TIENECOMPUTADOR
# Tipo de dato: object
# Total de valores únicos: 3
# Valores Únicos: ['Si' 'No' nan]...
#
# Columna: F_EDUCACIONMADRE
# Tipo de dato: object
# Total de valores únicos: 13
# Valores Únicos: ['Postgrado' 'Técnica o tecnológica incompleta'
#  'Secundaria (Bachillerato) completa' 'Primaria completa'
#  'Técnica o tecnológica completa' 'Secundaria (Bachillerato) incompleta'
#  'Educación profesional incompleta' 'Educación profesional completa'
#  'Primaria incompleta' nan 'Ninguno' 'No Aplica' 'No sabe']...
#
# Columna: RENDIMIENTO_GLOBAL
# Tipo de dato: object
# Total de valores únicos: 4
# Valores Únicos: ['medio-alto' 'bajo' 'alto' 'medio-bajo']...
#
# Columna: INDICADOR_1
# Tipo de dato: float64
# Total de valores únicos: 375
# Valores Únicos: [0.322 0.311 0.297 0.485 0.316 0.553 0.242 0.238 0.147 0.535 0.151 0.212
#  0.285 0.142 0.293 0.154 0.209 0.153 0.204 0.213]...
#
# Columna: INDICADOR_2
# Tipo de dato: float64
# Total de valores únicos: 342
# Valores Únicos: [0.208 0.215 0.214 0.172 0.232 0.142 0.299 0.316 0.407 0.122 0.399 0.284
#  0.249 0.395 0.239 0.252 0.379 0.307 0.388 0.3  ]...
#
# Columna: INDICADOR_3
# Tipo de dato: float64
# Total de valores únicos: 196
# Valores Únicos: [0.31  0.292 0.305 0.252 0.285 0.248 0.267 0.286 0.212 0.257 0.241 0.283
#  0.278 0.219 0.303 0.319 0.225 0.26  0.217 0.293]...
#
# Columna: INDICADOR_4
# Tipo de dato: float64
# Total de valores únicos: 276
# Valores Únicos: [0.267 0.264 0.19  0.294 0.175 0.308 0.29  0.328 0.167 0.292 0.324 0.289
#  0.287 0.266 0.258 0.282 0.314 0.295 0.301 0.026]...
